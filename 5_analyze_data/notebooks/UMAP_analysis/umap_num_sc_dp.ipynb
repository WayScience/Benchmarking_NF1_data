# %% [markdown]
# # Create 2D UMAP using number of single cells from DeepProfiler Projects

# %% [markdown]
# ## Import libraries

# %%
import pathlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# make random np operations reproducible
np.random.seed(0)

# %% [markdown]
# ## Nuclei DP Project

# %%
embeddings_path = pathlib.Path("../../data/norm_fs_embeddings_dp_nuc.csv.gz")
embeddings_data = pd.read_csv(embeddings_path, compression="gzip")

print(embeddings_data.shape)
embeddings_data.head()
# Out:
# (257, 15)
#    Location_Center_X  Location_Center_Y  Metadata_number_of_singlecells  \
# 0         652.868421         760.552632                               7
# 1         451.956522         477.682609                               7
# 2         528.925743         563.628713                               7
# 3         417.522321         702.272321                               7
# 4         166.436019         337.886256                               7
#
#    Metadata_Plate Metadata_Well  Metadata_Site Metadata_Plate_Map_Name  \
# 0               1            D6              3                  1_D6_3
# 1               1            D6              2                  1_D6_2
# 2               1            D6              2                  1_D6_2
# 3               1            D6              2                  1_D6_2
# 4               1            D6              4                  1_D6_4
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT
#
#    Metadata_Genotype_Replicate Metadata_Model     UMAP1     UMAP2
# 0                            1   efficientnet  4.264595  6.184330
# 1                            1   efficientnet  4.122251  3.966355
# 2                            1   efficientnet  5.334163  4.959183
# 3                            1   efficientnet  5.821635  3.165360
# 4                            1   efficientnet  4.885064  4.497552

# %%
plt.figure(figsize=(15, 12))

# Produce scatterplot with umap data, using metadata to color points
sns_plot = sns.scatterplot(
    data=embeddings_data,
    x=embeddings_data['UMAP1'],
    y=embeddings_data['UMAP2'],
    hue=embeddings_data["Metadata_number_of_singlecells"]
)
# Adjust legend
sns_plot.legend(
    loc="center left", bbox_to_anchor=(1, 0.5), title='number of single cells'
)
# Label axes, title
sns_plot.set_xlabel("UMAP 1")
sns_plot.set_ylabel("UMAP 2")
sns_plot.set_title("2 Dimensional UMAP For Number of Single Cells Per Well For Nuclei DeepProfiler Project")

save_path = pathlib.Path("UMAPs/2D_umap_nf1_num_sc_dp_nuc.png")

plt.savefig(save_path, bbox_inches="tight")

# %% [markdown]
# ## Cytoplasm DeepProfiler Project

# %%
embeddings_path = pathlib.Path("../../data/norm_fs_embeddings_dp_cyto.csv.gz")
embeddings_data = pd.read_csv(embeddings_path, compression="gzip")

print(embeddings_data.shape)
embeddings_data.head()
# Out:
# (256, 15)
#    Location_Center_X  Location_Center_Y  Metadata_number_of_singlecells  \
# 0         650.422472         736.706742                               7
# 1         443.544415         442.570800                               7
# 2         576.896764         565.425270                               7
# 3         413.186421         700.486766                               7
# 4         201.482682         373.559777                               7
#
#    Metadata_Plate Metadata_Well  Metadata_Site Metadata_Plate_Map_Name  \
# 0               1            D6              3                  1_D6_3
# 1               1            D6              2                  1_D6_2
# 2               1            D6              2                  1_D6_2
# 3               1            D6              2                  1_D6_2
# 4               1            D6              4                  1_D6_4
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT
#
#    Metadata_Genotype_Replicate Metadata_Model      UMAP1     UMAP2
# 0                            1   efficientnet  13.848951  2.563878
# 1                            1   efficientnet  10.949956  2.749159
# 2                            1   efficientnet  12.673684  2.965985
# 3                            1   efficientnet  11.994288  2.616522
# 4                            1   efficientnet  12.952534  3.528729

# %%
plt.figure(figsize=(15, 12))

# Produce scatterplot with umap data, using metadata to color points
sns_plot = sns.scatterplot(
    data=embeddings_data,
    x=embeddings_data['UMAP1'],
    y=embeddings_data['UMAP2'],
    hue=embeddings_data["Metadata_number_of_singlecells"]
)
# Adjust legend
sns_plot.legend(
    loc="center left", bbox_to_anchor=(1, 0.5), title='number of single cells'
)
# Label axes, title
sns_plot.set_xlabel("UMAP 1")
sns_plot.set_ylabel("UMAP 2")
sns_plot.set_title("2 Dimensional UMAP For Number of Single Cells Per Well For Cytoplasm DeepProfiler Project")

save_path = pathlib.Path("UMAPs/2D_umap_nf1_num_sc_dp_cyto.png")

plt.savefig(save_path, bbox_inches="tight")
