# %% [markdown]
# # Get 2D UMAP embeddings for NF1 DeepProfiler data

# %% [markdown]
# ## Import libraries

# %%
import pathlib
import pandas as pd
import umap

import UMAPutils as utils

# %% [markdown]
# ## Nuclei DeepProfiler Project

# %%
norm_data_nuc_path = pathlib.Path("../../../4_processing_features/data/nf1_sc_norm_fs_deepprofiler_nuc.csv.gz")
norm_data_nuc = pd.read_csv(norm_data_nuc_path, compression="gzip")

print(norm_data_nuc.shape)
norm_data_nuc.head()
# Out:
# (257, 3837)
#    Location_Center_X  Location_Center_Y  Metadata_Plate Metadata_Well  \
# 0         652.868421         760.552632               1            D6
# 1        1015.898477         209.162437               1            F6
# 2         387.202830         238.853774               1            F6
# 3         259.502304         250.400922               1            F6
# 4         351.255708         592.429224               1            F6
#
#    Metadata_Site Metadata_Plate_Map_Name  \
# 0              3                  1_D6_3
# 1              2                  1_F6_2
# 2              2                  1_F6_2
# 3              2                  1_F6_2
# 4              2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  ...  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
#
#    efficientnet_3830 efficientnet_3831  efficientnet_3832  efficientnet_3833  \
# 0          -0.514201          0.478099           0.484105          -0.212163
# 1          -0.250138         -0.740111          -0.190505          -0.690312
# 2          -0.358730         -0.183352           1.252175          -0.824103
# 3           0.540821         -0.724848           1.529958          -0.940500
# 4          -0.408348         -0.629579          -0.423012          -1.421697
#
#    efficientnet_3834  efficientnet_3835  efficientnet_3836  efficientnet_3837  \
# 0          -0.572581          -0.239070           0.907958           0.219261
# 1          -0.862426           4.039268          -1.532861          -1.382833
# 2          -0.185720          -0.380602           0.464281           0.019876
# 3          -0.649775          -0.212045           0.009084           0.655653
# 4           0.519623          -0.639995           0.571886          -1.031720
#
#    efficientnet_3838  efficientnet_3839
# 0           0.311132          -0.288884
# 1          -0.336643           0.894669
# 2           0.793334           1.428218
# 3          -0.164469           0.250813
# 4          -0.108736           0.103133
#
# [5 rows x 3837 columns]

# %%
metadata_dataframe, feature_data = utils.split_data(norm_data_nuc)

print(metadata_dataframe.shape)
metadata_dataframe.head()
# Out:
# (257, 10)
#    Metadata_Plate Metadata_Well  Metadata_Site Metadata_Plate_Map_Name  \
# 0               1            D6              3                  1_D6_3
# 1               1            F6              2                  1_F6_2
# 2               1            F6              2                  1_F6_2
# 3               1            F6              2                  1_F6_2
# 4               1            F6              2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT
#
#    Metadata_Genotype_Replicate Metadata_Model
# 0                            1   efficientnet
# 1                            1   efficientnet
# 2                            1   efficientnet
# 3                            1   efficientnet
# 4                            1   efficientnet

# %%
x_locations = norm_data_nuc["Location_Center_X"]
metadata_dataframe.insert(0, "Location_Center_X", x_locations)
y_locations = norm_data_nuc["Location_Center_Y"]
metadata_dataframe.insert(1, "Location_Center_Y", y_locations)

print(metadata_dataframe.shape)
metadata_dataframe.head()
# Out:
# (257, 12)
#    Location_Center_X  Location_Center_Y  Metadata_Plate Metadata_Well  \
# 0         652.868421         760.552632               1            D6
# 1        1015.898477         209.162437               1            F6
# 2         387.202830         238.853774               1            F6
# 3         259.502304         250.400922               1            F6
# 4         351.255708         592.429224               1            F6
#
#    Metadata_Site Metadata_Plate_Map_Name  \
# 0              3                  1_D6_3
# 1              2                  1_F6_2
# 2              2                  1_F6_2
# 3              2                  1_F6_2
# 4              2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT
#
#    Metadata_Genotype_Replicate Metadata_Model
# 0                            1   efficientnet
# 1                            1   efficientnet
# 2                            1   efficientnet
# 3                            1   efficientnet
# 4                            1   efficientnet

# %%
grouped_data = metadata_dataframe.groupby(["Metadata_Well"])['Metadata_Well'].count().reset_index(name='Metadata_number_of_singlecells')
grouped_data
# Out:
#   Metadata_Well  Metadata_number_of_singlecells
# 0            C6                              26
# 1            C7                              23
# 2            D6                               7
# 3            D7                              32
# 4            E6                              17
# 5            E7                              60
# 6            F6                              24
# 7            F7                              68

# %%
metadata_dataframe = metadata_dataframe.merge(grouped_data, on="Metadata_Well")
new_metadata_column = metadata_dataframe.pop("Metadata_number_of_singlecells")
metadata_dataframe.insert(2, "Metadata_number_of_singlecells", new_metadata_column)

# %%
feature_data = feature_data.drop(['Location_Center_X', 'Location_Center_Y'], axis=1)

print(feature_data.shape)
feature_data.head()
# Out:
# (257, 3825)
#    efficientnet_0  efficientnet_1  efficientnet_10  efficientnet_100  \
# 0        0.235069       -2.524998        -0.645525         -0.321902
# 1       -0.623746        1.037700         1.009706         -0.418760
# 2       -0.514111        0.838314         0.741559          0.007390
# 3       -0.590767       -0.004433        -1.088701          1.448685
# 4       -0.630595       -0.344079         1.002623         -0.005197
#
#    efficientnet_1000  efficientnet_1001  efficientnet_1002  efficientnet_1003  \
# 0           0.327108          -0.425506           0.109151          -0.522269
# 1           0.288138          -0.374713          -0.480356           0.142850
# 2          -0.343973           0.162181          -0.167019          -0.035345
# 3           0.253028           0.257632          -0.265532           3.350086
# 4          -1.205885           0.062935          -0.146158          -0.390066
#
#    efficientnet_1004  efficientnet_1005  ...  efficientnet_990  \
# 0          -0.248527          -1.001633  ...         -0.745270
# 1          -0.198695           0.062926  ...          2.162966
# 2           0.142035          -0.430217  ...         -0.247819
# 3           0.145468           0.271872  ...         -0.060401
# 4           0.045541          -0.298416  ...          0.459659
#
#    efficientnet_991  efficientnet_992  efficientnet_993  efficientnet_994  \
# 0         -0.594816         -0.450050         -0.059045         -0.647262
# 1         -0.373870          0.273352         -0.867027         -0.576743
# 2         -0.051758         -0.282056          0.498236         -0.575197
# 3          0.820960          0.148889         -1.753011          0.850738
# 4          0.901046         -1.393525          0.293504         -0.724374
#
#    efficientnet_995  efficientnet_996  efficientnet_997  efficientnet_998  \
# 0         -0.209944          0.866904          0.236938         -0.026535
# 1          0.107865         -0.154136         -0.675416          0.090121
# 2         -0.652407         -0.175582          0.287247         -0.310507
# 3          1.141865          1.014065         -0.894101          1.714785
# 4         -0.392195         -0.502709         -0.853243          1.176767
#
#    efficientnet_999
# 0         -0.276103
# 1          2.199593
# 2         -0.001377
# 3          3.437282
# 4         -0.377427
#
# [5 rows x 3825 columns]

# %%
fit = umap.UMAP(random_state=0, n_components=2)

embeddings = pd.DataFrame(
        fit.fit_transform(feature_data), columns=["UMAP1", "UMAP2"]
    )
embeddings
# Out:
#         UMAP1     UMAP2
# 0    4.264595  6.184330
# 1    4.122251  3.966355
# 2    5.334163  4.959183
# 3    5.821635  3.165360
# 4    4.885064  4.497552
# ..        ...       ...
# 252  5.298770  1.950539
# 253  5.954596  3.117260
# 254  5.501772  1.967708
# 255  5.394285  3.641819
# 256  5.483860  3.615038
#
# [257 rows x 2 columns]

# %%
save_path = pathlib.Path('../../data/norm_fs_embeddings_dp_nuc.csv.gz')

norm_fs_embeddings_data_dp_nuc = utils.merge_metadata_embeddings(metadata_dataframe, embeddings, save_path)

print(norm_fs_embeddings_data_dp_nuc.shape)
norm_fs_embeddings_data_dp_nuc.head()
# Out:
# (257, 15)
#    Location_Center_X  Location_Center_Y  Metadata_number_of_singlecells  \
# 0         652.868421         760.552632                               7
# 1         451.956522         477.682609                               7
# 2         528.925743         563.628713                               7
# 3         417.522321         702.272321                               7
# 4         166.436019         337.886256                               7
#
#    Metadata_Plate Metadata_Well  Metadata_Site Metadata_Plate_Map_Name  \
# 0               1            D6              3                  1_D6_3
# 1               1            D6              2                  1_D6_2
# 2               1            D6              2                  1_D6_2
# 3               1            D6              2                  1_D6_2
# 4               1            D6              4                  1_D6_4
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT
#
#    Metadata_Genotype_Replicate Metadata_Model     UMAP1     UMAP2
# 0                            1   efficientnet  4.264595  6.184330
# 1                            1   efficientnet  4.122251  3.966355
# 2                            1   efficientnet  5.334163  4.959183
# 3                            1   efficientnet  5.821635  3.165360
# 4                            1   efficientnet  4.885064  4.497552

# %% [markdown]
# ## Cytoplasm DeepProfiler Project

# %%
norm_data_cyto_path = pathlib.Path("../../../4_processing_features/data/nf1_sc_norm_fs_deepprofiler_cyto.csv.gz")
norm_data_cyto = pd.read_csv(norm_data_cyto_path, compression="gzip")

print(norm_data_cyto.shape)
norm_data_cyto.head()
# Out:
# (256, 3844)
#    Location_Center_X  Location_Center_Y  Metadata_Plate Metadata_Well  \
# 0         650.422472         736.706742               1            D6
# 1         949.182667         256.734667               1            F6
# 2         454.460081         265.797023               1            F6
# 3         211.165254         274.745763               1            F6
# 4         375.125130         566.646507               1            F6
#
#    Metadata_Site Metadata_Plate_Map_Name  \
# 0              3                  1_D6_3
# 1              2                  1_F6_2
# 2              2                  1_F6_2
# 3              2                  1_F6_2
# 4              2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  ...  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
#
#    efficientnet_3830 efficientnet_3831  efficientnet_3832  efficientnet_3833  \
# 0          -0.034014          0.859518          -0.025713          -0.729571
# 1          -0.021109          0.185511          -0.612227           2.925806
# 2          -0.158382         -0.810211          -0.720877           0.127869
# 3          -0.831178         -0.614643          -0.168719          -0.343051
# 4          -0.118977          0.065025          -0.431710          -0.547652
#
#    efficientnet_3834  efficientnet_3835  efficientnet_3836  efficientnet_3837  \
# 0           0.267231          -0.847366          -1.090082           0.566786
# 1          -0.927761          -0.304350          -0.031065           0.626545
# 2           1.199453           1.977439          -0.844405          -0.299137
# 3          -0.219525           0.493543          -0.751189           0.684554
# 4          -0.538548           0.022739           0.639954           0.393346
#
#    efficientnet_3838  efficientnet_3839
# 0          -0.024363           0.230463
# 1          -0.408060          -1.211616
# 2          -0.775166          -0.292143
# 3           0.159646           0.196000
# 4           0.235406           0.932857
#
# [5 rows x 3844 columns]

# %%
metadata_dataframe, feature_data = utils.split_data(norm_data_cyto)

print(metadata_dataframe.shape)
metadata_dataframe.head()
# Out:
# (256, 10)
#    Metadata_Plate Metadata_Well  Metadata_Site Metadata_Plate_Map_Name  \
# 0               1            D6              3                  1_D6_3
# 1               1            F6              2                  1_F6_2
# 2               1            F6              2                  1_F6_2
# 3               1            F6              2                  1_F6_2
# 4               1            F6              2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT
#
#    Metadata_Genotype_Replicate Metadata_Model
# 0                            1   efficientnet
# 1                            1   efficientnet
# 2                            1   efficientnet
# 3                            1   efficientnet
# 4                            1   efficientnet

# %%
x_locations = norm_data_cyto["Location_Center_X"]
metadata_dataframe.insert(0, "Location_Center_X", x_locations)
y_locations = norm_data_cyto["Location_Center_Y"]
metadata_dataframe.insert(1, "Location_Center_Y", y_locations)

print(metadata_dataframe.shape)
metadata_dataframe.head()
# Out:
# (256, 12)
#    Location_Center_X  Location_Center_Y  Metadata_Plate Metadata_Well  \
# 0         650.422472         736.706742               1            D6
# 1         949.182667         256.734667               1            F6
# 2         454.460081         265.797023               1            F6
# 3         211.165254         274.745763               1            F6
# 4         375.125130         566.646507               1            F6
#
#    Metadata_Site Metadata_Plate_Map_Name  \
# 0              3                  1_D6_3
# 1              2                  1_F6_2
# 2              2                  1_F6_2
# 3              2                  1_F6_2
# 4              2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT
#
#    Metadata_Genotype_Replicate Metadata_Model
# 0                            1   efficientnet
# 1                            1   efficientnet
# 2                            1   efficientnet
# 3                            1   efficientnet
# 4                            1   efficientnet

# %%
grouped_data = metadata_dataframe.groupby(["Metadata_Well"])['Metadata_Well'].count().reset_index(name='Metadata_number_of_singlecells')
grouped_data
# Out:
#   Metadata_Well  Metadata_number_of_singlecells
# 0            C6                              26
# 1            C7                              23
# 2            D6                               7
# 3            D7                              32
# 4            E6                              17
# 5            E7                              59
# 6            F6                              24
# 7            F7                              68

# %%
metadata_dataframe = metadata_dataframe.merge(grouped_data, on="Metadata_Well")
new_metadata_column = metadata_dataframe.pop("Metadata_number_of_singlecells")
metadata_dataframe.insert(2, "Metadata_number_of_singlecells", new_metadata_column)

# %%
feature_data = feature_data.drop(['Location_Center_X', 'Location_Center_Y'], axis=1)

print(feature_data.shape)
feature_data.head()
# Out:
# (256, 3832)
#    efficientnet_0  efficientnet_1  efficientnet_10  efficientnet_100  \
# 0        0.518928       -1.030638        -0.176670         -0.658651
# 1       -0.532346        0.038914        -0.481328         -0.494546
# 2        0.717823        1.356706         0.209188         -0.497367
# 3       -0.083235       -0.367833        -0.047480          1.570235
# 4       -0.698319       -0.016846        -0.113460          0.370509
#
#    efficientnet_1000  efficientnet_1001  efficientnet_1002  efficientnet_1003  \
# 0          -0.231146          -0.410912           1.258987           0.528172
# 1          -0.460594          -0.361398          -0.503176          -0.468075
# 2          -0.710925          -0.286272          -0.258021          -0.265605
# 3          -0.601118           0.391697           0.271105           2.680643
# 4          -0.797704          -0.594630          -0.816060          -0.001589
#
#    efficientnet_1004  efficientnet_1005  ...  efficientnet_990  \
# 0          -0.462594          -0.798068  ...         -0.749512
# 1           0.429030          -0.015511  ...          0.111416
# 2          -0.434462          -0.365862  ...         -0.585437
# 3          -0.773746           0.150493  ...          1.544803
# 4          -0.834368          -0.709130  ...         -0.374620
#
#    efficientnet_991  efficientnet_992  efficientnet_993  efficientnet_994  \
# 0         -0.732841          0.767652         -0.881471         -0.512916
# 1         -0.817825         -1.079264         -1.538474          0.100065
# 2         -0.748314          0.562900         -0.810733         -0.278916
# 3          0.140156          0.679623          0.881273          1.707555
# 4          0.715716         -0.446599         -0.323712         -0.663026
#
#    efficientnet_995  efficientnet_996  efficientnet_997  efficientnet_998  \
# 0         -0.123882         -0.047746         -0.188216          0.222457
# 1         -0.407861         -0.273762         -1.445162          0.608907
# 2          0.418900         -0.477898          0.500113         -0.110842
# 3         -0.419930         -0.169850         -0.467632         -0.659259
# 4         -0.708899         -0.434248         -0.835424          0.168417
#
#    efficientnet_999
# 0          0.343864
# 1         -0.422729
# 2          0.531526
# 3         -0.136917
# 4          0.139753
#
# [5 rows x 3832 columns]

# %%
fit = umap.UMAP(random_state=0, n_components=2)

embeddings = pd.DataFrame(
        fit.fit_transform(feature_data), columns=["UMAP1", "UMAP2"]
    )
embeddings
# Out:
#          UMAP1     UMAP2
# 0    13.848951  2.563878
# 1    10.949956  2.749159
# 2    12.673684  2.965985
# 3    11.994288  2.616522
# 4    12.952534  3.528729
# ..         ...       ...
# 251   9.114523  5.192198
# 252   8.850242  5.101776
# 253   9.071429  5.187535
# 254   9.066143  5.200025
# 255  10.897064  3.686829
#
# [256 rows x 2 columns]

# %%
save_path = pathlib.Path('../../data/norm_fs_embeddings_dp_cyto.csv.gz')

norm_fs_embeddings_data_dp_cyto = utils.merge_metadata_embeddings(metadata_dataframe, embeddings, save_path)

print(norm_fs_embeddings_data_dp_cyto.shape)
norm_fs_embeddings_data_dp_cyto.head()
# Out:
# (256, 15)
#    Location_Center_X  Location_Center_Y  Metadata_number_of_singlecells  \
# 0         650.422472         736.706742                               7
# 1         443.544415         442.570800                               7
# 2         576.896764         565.425270                               7
# 3         413.186421         700.486766                               7
# 4         201.482682         373.559777                               7
#
#    Metadata_Plate Metadata_Well  Metadata_Site Metadata_Plate_Map_Name  \
# 0               1            D6              3                  1_D6_3
# 1               1            D6              2                  1_D6_2
# 2               1            D6              2                  1_D6_2
# 3               1            D6              2                  1_D6_2
# 4               1            D6              4                  1_D6_4
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT
#
#    Metadata_Genotype_Replicate Metadata_Model      UMAP1     UMAP2
# 0                            1   efficientnet  13.848951  2.563878
# 1                            1   efficientnet  10.949956  2.749159
# 2                            1   efficientnet  12.673684  2.965985
# 3                            1   efficientnet  11.994288  2.616522
# 4                            1   efficientnet  12.952534  3.528729
