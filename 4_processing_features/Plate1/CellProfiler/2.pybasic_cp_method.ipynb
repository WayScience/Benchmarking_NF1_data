# %% [markdown]
# # Process single cell morphology features for CellProfiler readouts - PyBaSiC and CellProfiler Method

# %% [markdown]
# ## Import Libraries

# %%
import pathlib
import pandas as pd

from pycytominer import normalize, feature_select
from pycytominer.cyto_utils import cells, output, util

# %% [markdown]
# ## Set up paths to CellProfiler directory and outputs

# %%
# Set file and directory constants
cp_dir = "../../../CellProfiler_pipelines"
output_dir = "../../data/Plate1/CellProfiler"

# %% [markdown]
# ## Set up paths to sqlite files and outputs

# %%
# Set name and path of .sqlite file and path to metadata
sql_file_pbcp = "NF1_data_pybasic_cp_plate1.sqlite"
single_cell_file_pbcp = f"sqlite:///{cp_dir}/Analysis_Output/Plate1_Output/{sql_file_pbcp}"
platemap_file = f"{cp_dir}/Metadata/platemap_NF1_CP.csv"

# Set path with name for outputted data
sc_output_file_pbcp = pathlib.Path(f"{output_dir}/nf1_sc_pybasic_cellprofiler.csv.gz")
sc_norm_output_file_pbcp = pathlib.Path(f"{output_dir}/nf1_sc_norm_pybasic_cellprofiler.csv.gz")
sc_norm_fs_output_file_pbcp = pathlib.Path(f"{output_dir}/nf1_sc_norm_fs_pybasic_cellprofiler.csv.gz")

# %% [markdown]
# ## Set up names for linking columns between tables in the database file

# %%
# Define custom linking columns between compartments
linking_cols = {
    "Per_Cytoplasm": {
        "Per_Cells": "Cytoplasm_Parent_Cells",
        "Per_Nuclei": "Cytoplasm_Parent_Nuclei",
    },
    "Per_Cells": {"Per_Cytoplasm": "Cells_Number_Object_Number"},
    "Per_Nuclei": {"Per_Cytoplasm": "Nuclei_Number_Object_Number"},
}

# %% [markdown]
# ## Load in platemap

# %%
# Load platemap file
platemap_df = pd.read_csv(platemap_file)
platemap_df
# Out:
#   WellRow  WellCol well_position gene_name genotype
# 0       C        6            C6       NF1       WT
# 1       C        7            C7       NF1     Null
# 2       D        6            D6       NF1       WT
# 3       D        7            D7       NF1     Null
# 4       E        6            E6       NF1       WT
# 5       E        7            E7       NF1     Null
# 6       F        6            F6       NF1       WT
# 7       F        7            F7       NF1     Null

# %% [markdown]
# ## Set up `SingleCells` class from Pycytominer

# %%
# Instantiate SingleCells class
sc_pbcp = cells.SingleCells(
    sql_file=single_cell_file_pbcp,
    compartments=["Per_Cells", "Per_Cytoplasm", "Per_Nuclei"],
    compartment_linking_cols=linking_cols,
    image_feature_categories=["Correlation", "Texture", "Granularity"],
    add_image_features=True,
    load_image_data=True,
    image_table_name="Per_Image",
    strata=["Image_Metadata_Well", "Image_Metadata_Plate"],
    merge_cols=["ImageNumber"],
    image_cols=["ImageNumber"]
)
# Out:
# /home/jenna/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pycytominer/cyto_utils/util.py:61: UserWarning: Non-canonical compartment detected: per_cells, per_cytoplasm, per_nuclei
#   warnings.warn(warn_str)

# %% [markdown]
# ## Merge single cells

# %%
# Merge single cells across compartments
anno_kwargs = {"join_on": ["Metadata_well_position", "Image_Metadata_Well"]}

sc_df_pbcp = sc_pbcp.merge_single_cells(
    platemap=platemap_file,
    **anno_kwargs,
)

# Save level 2 data as a csv
output(sc_df_pbcp, sc_output_file_pbcp)

print(sc_df_pbcp.shape)
sc_df_pbcp.head()
# Out:
# (241, 1209)
#   Metadata_WellRow  Metadata_WellCol Metadata_gene_name Metadata_genotype  \
# 0                C                 6                NF1                WT
# 1                C                 6                NF1                WT
# 2                C                 6                NF1                WT
# 3                C                 6                NF1                WT
# 4                C                 6                NF1                WT
#
#   Metadata_ImageNumber Metadata_Plate Metadata_Well  \
# 0                    1            001            C6
# 1                    1            001            C6
# 2                    1            001            C6
# 3                    1            001            C6
# 4                    1            001            C6
#
#   Metadata_Cytoplasm_Parent_Cells Metadata_Cytoplasm_Parent_Nuclei  \
# 0                               1                                3
# 1                               2                                4
# 2                               3                                5
# 3                               4                                7
# 4                               5                                8
#
#   Metadata_Cells_Number_Object_Number  ...  \
# 0                                   1  ...
# 1                                   2  ...
# 2                                   3  ...
# 3                                   4  ...
# 4                                   5  ...
#
#   Nuclei_Texture_Variance_DAPI_3_02_256 Nuclei_Texture_Variance_DAPI_3_03_256  \
# 0                            1238.72285                           1179.250712
# 1                           1321.816347                            1230.24571
# 2                           1186.118097                           1152.224625
# 3                            865.094181                            839.097694
# 4                           1159.793785                           1147.506816
#
#   Nuclei_Texture_Variance_GFP_3_00_256 Nuclei_Texture_Variance_GFP_3_01_256  \
# 0                           655.943302                           615.439093
# 1                           514.140384                           494.307862
# 2                           291.519216                           265.656395
# 3                           218.430012                           194.968446
# 4                            303.06524                           296.152842
#
#   Nuclei_Texture_Variance_GFP_3_02_256 Nuclei_Texture_Variance_GFP_3_03_256  \
# 0                           607.532978                           583.378878
# 1                           498.533943                           448.867667
# 2                           266.725373                           238.545128
# 3                           191.831872                            193.43147
# 4                            306.75981                           282.561259
#
#   Nuclei_Texture_Variance_RFP_3_00_256 Nuclei_Texture_Variance_RFP_3_01_256  \
# 0                           262.401005                           257.912781
# 1                            96.646848                            98.695691
# 2                            91.570219                            87.388137
# 3                            93.765059                            93.809022
# 4                           616.983573                           620.487106
#
#   Nuclei_Texture_Variance_RFP_3_02_256 Nuclei_Texture_Variance_RFP_3_03_256
# 0                           263.508342                           265.420711
# 1                           103.741923                            95.047508
# 2                            98.279571                            97.734207
# 3                            91.933528                            91.105865
# 4                           606.813743                           608.887347
#
# [5 rows x 1209 columns]

# %% [markdown]
# ## Normalize data

# %%
# Normalize single cell data and write to file
normalize_sc_pbcp = normalize(
    sc_df_pbcp,
    method="standardize"
)

output(normalize_sc_pbcp, sc_norm_output_file_pbcp)

print(normalize_sc_pbcp.shape)
normalize_sc_pbcp.head()
# Out:
# (241, 1209)
#   Metadata_WellRow  Metadata_WellCol Metadata_gene_name Metadata_genotype  \
# 0                C                 6                NF1                WT
# 1                C                 6                NF1                WT
# 2                C                 6                NF1                WT
# 3                C                 6                NF1                WT
# 4                C                 6                NF1                WT
#
#   Metadata_ImageNumber Metadata_Plate Metadata_Well  \
# 0                    1            001            C6
# 1                    1            001            C6
# 2                    1            001            C6
# 3                    1            001            C6
# 4                    1            001            C6
#
#   Metadata_Cytoplasm_Parent_Cells Metadata_Cytoplasm_Parent_Nuclei  \
# 0                               1                                3
# 1                               2                                4
# 2                               3                                5
# 3                               4                                7
# 4                               5                                8
#
#   Metadata_Cells_Number_Object_Number  ...  \
# 0                                   1  ...
# 1                                   2  ...
# 2                                   3  ...
# 3                                   4  ...
# 4                                   5  ...
#
#   Nuclei_Texture_Variance_DAPI_3_02_256  \
# 0                             -0.449210
# 1                             -0.329431
# 2                             -0.525041
# 3                             -0.987799
# 4                             -0.562987
#
#    Nuclei_Texture_Variance_DAPI_3_03_256  \
# 0                              -0.456870
# 1                              -0.379423
# 2                              -0.497915
# 3                              -0.973467
# 4                              -0.505080
#
#    Nuclei_Texture_Variance_GFP_3_00_256  Nuclei_Texture_Variance_GFP_3_01_256  \
# 0                              0.795275                              0.738860
# 1                              0.474068                              0.460919
# 2                             -0.030206                             -0.063733
# 3                             -0.195765                             -0.225930
# 4                             -0.004053                              0.006243
#
#    Nuclei_Texture_Variance_GFP_3_02_256  Nuclei_Texture_Variance_GFP_3_03_256  \
# 0                              0.676636                              0.658115
# 1                              0.431895                              0.351245
# 2                             -0.088596                             -0.128580
# 3                             -0.256758                             -0.231501
# 4                              0.001295                             -0.028163
#
#    Nuclei_Texture_Variance_RFP_3_00_256  Nuclei_Texture_Variance_RFP_3_01_256  \
# 0                              1.079249                              1.051704
# 1                              0.080868                              0.096177
# 2                              0.050290                              0.028316
# 3                              0.063510                              0.066850
# 4                              3.214995                              3.227661
#
#    Nuclei_Texture_Variance_RFP_3_02_256  Nuclei_Texture_Variance_RFP_3_03_256
# 0                              1.084199                              1.111437
# 1                              0.123054                              0.075878
# 2                              0.090193                              0.092208
# 3                              0.052016                              0.051920
# 4                              3.149502                              3.199090
#
# [5 rows x 1209 columns]

# %% [markdown]
# ## Feature selection

# %%
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "blocklist",
]

feature_select_norm_sc_pbcp = feature_select(
    normalize_sc_pbcp,
    operation=feature_select_ops
)

output(feature_select_norm_sc_pbcp, sc_norm_fs_output_file_pbcp)

print(feature_select_norm_sc_pbcp.shape)
feature_select_norm_sc_pbcp.head()
# Out:
# (241, 446)
#   Metadata_WellRow  Metadata_WellCol Metadata_gene_name Metadata_genotype  \
# 0                C                 6                NF1                WT
# 1                C                 6                NF1                WT
# 2                C                 6                NF1                WT
# 3                C                 6                NF1                WT
# 4                C                 6                NF1                WT
#
#   Metadata_ImageNumber Metadata_Plate Metadata_Well  \
# 0                    1            001            C6
# 1                    1            001            C6
# 2                    1            001            C6
# 3                    1            001            C6
# 4                    1            001            C6
#
#   Metadata_Cytoplasm_Parent_Cells Metadata_Cytoplasm_Parent_Nuclei  \
# 0                               1                                3
# 1                               2                                4
# 2                               3                                5
# 3                               4                                7
# 4                               5                                8
#
#   Metadata_Cells_Number_Object_Number  ...  \
# 0                                   1  ...
# 1                                   2  ...
# 2                                   3  ...
# 3                                   4  ...
# 4                                   5  ...
#
#   Nuclei_Texture_InfoMeas2_DAPI_3_03_256  \
# 0                               0.700737
# 1                               0.697642
# 2                               0.505022
# 3                               0.419720
# 4                               0.686710
#
#    Nuclei_Texture_InfoMeas2_GFP_3_02_256  \
# 0                               0.965755
# 1                               1.122196
# 2                               0.664303
# 3                               0.305376
# 4                               0.586884
#
#    Nuclei_Texture_InfoMeas2_RFP_3_00_256  \
# 0                               0.438415
# 1                              -0.156684
# 2                              -0.671115
# 3                              -0.109890
# 4                               1.036074
#
#    Nuclei_Texture_InfoMeas2_RFP_3_01_256  \
# 0                               0.534472
# 1                               0.382543
# 2                              -0.703113
# 3                               0.498398
# 4                               1.178635
#
#    Nuclei_Texture_InfoMeas2_RFP_3_02_256  \
# 0                               0.943146
# 1                               1.009916
# 2                               0.135464
# 3                               1.252383
# 4                               1.289660
#
#    Nuclei_Texture_InfoMeas2_RFP_3_03_256  \
# 0                               1.380947
# 1                               0.293588
# 2                               0.827720
# 3                               0.271598
# 4                               1.428171
#
#    Nuclei_Texture_InverseDifferenceMoment_GFP_3_00_256  \
# 0                                          -0.347949
# 1                                          -1.463565
# 2                                          -0.240754
# 3                                          -0.113838
# 4                                          -0.765977
#
#    Nuclei_Texture_SumEntropy_DAPI_3_03_256  \
# 0                                 1.057741
# 1                                 1.105301
# 2                                 0.971345
# 3                                 0.768712
# 4                                 0.963674
#
#    Nuclei_Texture_SumVariance_DAPI_3_01_256  \
# 0                                 -0.273991
# 1                                 -0.168553
# 2                                 -0.424140
# 3                                 -0.837286
# 4                                 -0.493886
#
#    Nuclei_Texture_SumVariance_RFP_3_03_256
# 0                                 1.118008
# 1                                 0.042082
# 2                                 0.116954
# 3                                 0.021548
# 4                                 3.089762
#
# [5 rows x 446 columns]

# %% [markdown]
# ---
#
# ### Visualize basic count statistics

# %%
sc_df_pbcp.Metadata_genotype.value_counts()
# Out:
# Null    172
# WT       69
# Name: Metadata_genotype, dtype: int64

# %%
pd.crosstab(sc_df_pbcp.Metadata_genotype, sc_df_pbcp.Metadata_Well)
# Out:
# Metadata_Well      C6  C7  D6  D7  E6  E7  F6  F7
# Metadata_genotype
# Null                0  22   0  27   0  56   0  67
# WT                 25   0   7   0  15   0  22   0
