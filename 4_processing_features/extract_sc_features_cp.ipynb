# %% [markdown]
# # Process single cell morphology features for CellProfiler readouts

# %% [markdown]
# ## Import Libraries

# %%
import pathlib
import pandas as pd

from pycytominer import normalize, feature_select
from pycytominer.cyto_utils import cells, output

# %% [markdown]
# ## Set up paths to CellProfiler directory and outputs

# %%
# Set file and directory constants
cp_dir = "../CellProfiler_pipelines"
output_dir = "data"

# %% [markdown]
# ### Plate 1

# %%
# Set name and path of .sqlite file and path to metadata
sql_file = "NF1_data_allcp_plate1.sqlite"
single_cell_file = f"sqlite:///{cp_dir}/Analysis_Output/Plate1_Output/{sql_file}"
platemap_file = f"{cp_dir}/Metadata/platemap_NF1_CP.csv"

# Set path with name for outputted data
sc_output_file = pathlib.Path(f"{output_dir}/nf1_sc_cellprofiler.csv.gz")
sc_norm_output_file = pathlib.Path(f"{output_dir}/nf1_sc_norm_cellprofiler.csv.gz")
sc_norm_fs_output_file = pathlib.Path(f"{output_dir}/nf1_sc_norm_fs_cellprofiler.csv.gz")

# %% [markdown]
# ### Plate 2

# %%
# Set name and path of .sqlite file and path to metadata
sql_file2 = "NF1_data_plate2.sqlite"
single_cell_file2 = f"sqlite:///{cp_dir}/Analysis_Output/Plate2_Output/{sql_file2}"
platemap_file2 = f"{cp_dir}/Metadata/platemap_NF1_CP_Plate2.csv"

# Set path with name for outputted data
sc_output_file2 = pathlib.Path(f"{output_dir}/nf1_sc_cellprofiler_plate2.csv.gz")
sc_norm_output_file2 = pathlib.Path(f"{output_dir}/nf1_sc_norm_cellprofiler_plate2.csv.gz")
sc_norm_fs_output_file2 = pathlib.Path(f"{output_dir}/nf1_sc_norm_fs_cellprofiler_plate2.csv.gz")

# %% [markdown]
# ## Set up names for linking columns between tables in the database file

# %%
# Define custom linking columns between compartments
linking_cols = {
    "Per_Cytoplasm": {
        "Per_Cells": "Cytoplasm_Parent_Cells",
        "Per_Nuclei": "Cytoplasm_Parent_Nuclei",
    },
    "Per_Cells": {"Per_Cytoplasm": "Cells_Number_Object_Number"},
    "Per_Nuclei": {"Per_Cytoplasm": "Nuclei_Number_Object_Number"},
}

# %% [markdown]
# ## Plate 1

# %% [markdown]
# ### Load and view platemap file

# %%
# Load platemap file
platemap_df = pd.read_csv(platemap_file)
platemap_df
# Out:
#   WellRow  WellCol well_position gene_name genotype
# 0       C        6            C6       NF1       WT
# 1       C        7            C7       NF1     Null
# 2       D        6            D6       NF1       WT
# 3       D        7            D7       NF1     Null
# 4       E        6            E6       NF1       WT
# 5       E        7            E7       NF1     Null
# 6       F        6            F6       NF1       WT
# 7       F        7            F7       NF1     Null

# %% [markdown]
# ### Set up `SingleCells` class from Pycytominer

# %%
# Instantiate SingleCells class
sc = cells.SingleCells(
    sql_file=single_cell_file,
    compartments=["Per_Cells", "Per_Cytoplasm", "Per_Nuclei"],
    compartment_linking_cols=linking_cols,
    image_table_name="Per_Image",
    strata=["Image_Metadata_Well", "Image_Metadata_Plate"],
    merge_cols=["ImageNumber"],
    image_cols="ImageNumber",
    load_image_data=True
)
# Out:
# /home/jenna/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pycytominer/cyto_utils/util.py:61: UserWarning: Non-canonical compartment detected: per_cells, per_cytoplasm, per_nuclei
#   warnings.warn(warn_str)

# %% [markdown]
# ### Merge single cells

# %%
# Merge single cells across compartments
anno_kwargs = {"join_on": ["Metadata_well_position", "Image_Metadata_Well"]}

sc_df = sc.merge_single_cells(
    platemap=platemap_df,
    **anno_kwargs,
)

# Save level 2 data as a csv
output(sc_df, sc_output_file)

print(sc_df.shape)
sc_df.head()
# Out:
# (242, 1053)
#   Metadata_WellRow  Metadata_WellCol Metadata_gene_name Metadata_genotype  \
# 0                C                 6                NF1                WT
# 1                C                 6                NF1                WT
# 2                C                 6                NF1                WT
# 3                C                 6                NF1                WT
# 4                C                 6                NF1                WT
#
#   Metadata_ImageNumber Metadata_Plate Metadata_Well  \
# 0                    1            001            C6
# 1                    1            001            C6
# 2                    1            001            C6
# 3                    1            001            C6
# 4                    1            001            C6
#
#   Metadata_Cytoplasm_Parent_Cells Metadata_Cytoplasm_Parent_Nuclei  \
# 0                               1                                3
# 1                               2                                4
# 2                               3                                5
# 3                               4                                7
# 4                               5                                8
#
#   Metadata_Cells_Number_Object_Number  ...  \
# 0                                   1  ...
# 1                                   2  ...
# 2                                   3  ...
# 3                                   4  ...
# 4                                   5  ...
#
#   Nuclei_Texture_SumVariance_RFP_3_02_256  \
# 0                              513.054347
# 1                              238.544841
# 2                               281.33372
# 3                              422.412133
# 4                             1778.355949
#
#   Nuclei_Texture_SumVariance_RFP_3_03_256  \
# 0                              531.003368
# 1                              187.499797
# 2                              291.161183
# 3                              355.502678
# 4                             1715.661141
#
#   Nuclei_Texture_Variance_GFP_3_00_256 Nuclei_Texture_Variance_GFP_3_01_256  \
# 0                           653.826838                           618.063979
# 1                           332.941295                            317.56745
# 2                           432.829034                           398.306003
# 3                           211.898029                           189.348918
# 4                            306.13973                           295.581509
#
#   Nuclei_Texture_Variance_GFP_3_02_256 Nuclei_Texture_Variance_GFP_3_03_256  \
# 0                           606.832257                           590.114791
# 1                           321.873215                           292.116754
# 2                           401.091835                            358.84984
# 3                             186.3333                           188.292692
# 4                           310.469726                            287.78839
#
#   Nuclei_Texture_Variance_RFP_3_00_256 Nuclei_Texture_Variance_RFP_3_01_256  \
# 0                           147.195839                           144.355017
# 1                            60.632767                            61.876198
# 2                            74.837374                            71.033793
# 3                           113.059608                           113.194846
# 4                           496.084704                           502.046808
#
#   Nuclei_Texture_Variance_RFP_3_02_256 Nuclei_Texture_Variance_RFP_3_03_256
# 0                           148.179465                           148.875403
# 1                            65.202076                            60.022847
# 2                            80.523205                            80.845266
# 3                           110.997393                            109.83439
# 4                           490.259298                           491.171009
#
# [5 rows x 1053 columns]

# %% [markdown]
# ### Normalize Data

# %%
# Normalize single cell data and write to file
normalize_sc_df = normalize(
    sc_df,
    method="standardize"
)

output(normalize_sc_df, sc_norm_output_file)

print(normalize_sc_df.shape)
normalize_sc_df.head()
# Out:
# (242, 1053)
#   Metadata_WellRow  Metadata_WellCol Metadata_gene_name Metadata_genotype  \
# 0                C                 6                NF1                WT
# 1                C                 6                NF1                WT
# 2                C                 6                NF1                WT
# 3                C                 6                NF1                WT
# 4                C                 6                NF1                WT
#
#   Metadata_ImageNumber Metadata_Plate Metadata_Well  \
# 0                    1            001            C6
# 1                    1            001            C6
# 2                    1            001            C6
# 3                    1            001            C6
# 4                    1            001            C6
#
#   Metadata_Cytoplasm_Parent_Cells Metadata_Cytoplasm_Parent_Nuclei  \
# 0                               1                                3
# 1                               2                                4
# 2                               3                                5
# 3                               4                                7
# 4                               5                                8
#
#   Metadata_Cells_Number_Object_Number  ...  \
# 0                                   1  ...
# 1                                   2  ...
# 2                                   3  ...
# 3                                   4  ...
# 4                                   5  ...
#
#   Nuclei_Texture_SumVariance_RFP_3_02_256  \
# 0                                0.694106
# 1                                0.056414
# 2                                0.155813
# 3                                0.483542
# 4                                3.633435
#
#    Nuclei_Texture_SumVariance_RFP_3_03_256  \
# 0                                 0.804706
# 1                                -0.036084
# 2                                 0.217647
# 3                                 0.375135
# 4                                 3.704379
#
#    Nuclei_Texture_Variance_GFP_3_00_256  Nuclei_Texture_Variance_GFP_3_01_256  \
# 0                              0.437881                              0.406082
# 1                             -0.069536                             -0.073583
# 2                              0.088417                              0.055295
# 3                             -0.260942                             -0.278251
# 4                             -0.111917                             -0.108678
#
#    Nuclei_Texture_Variance_GFP_3_02_256  Nuclei_Texture_Variance_GFP_3_03_256  \
# 0                              0.358158                              0.358081
# 1                             -0.088878                             -0.116121
# 2                              0.035398                             -0.009929
# 3                             -0.301509                             -0.281335
# 4                             -0.106767                             -0.123008
#
#    Nuclei_Texture_Variance_RFP_3_00_256  Nuclei_Texture_Variance_RFP_3_01_256  \
# 0                              0.760504                              0.736324
# 1                              0.001109                              0.015249
# 2                              0.125722                              0.095310
# 3                              0.461035                              0.463905
# 4                              3.821213                              3.863460
#
#    Nuclei_Texture_Variance_RFP_3_02_256  Nuclei_Texture_Variance_RFP_3_03_256
# 0                              0.765755                              0.781857
# 1                              0.039691                             -0.000841
# 2                              0.173753                              0.182583
# 3                              0.440407                              0.437947
# 4                              3.759005                              3.797123
#
# [5 rows x 1053 columns]

# %% [markdown]
# ### Feature Selection

# %%
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "blocklist",
]

feature_select_norm_sc_df = feature_select(
    normalize_sc_df,
    operation=feature_select_ops
)

output(feature_select_norm_sc_df, sc_norm_fs_output_file)

print(feature_select_norm_sc_df.shape)
feature_select_norm_sc_df.head()
# Out:
# /home/jenna/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/numpy/lib/function_base.py:2829: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/jenna/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/numpy/lib/function_base.py:2830: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# (242, 408)
#   Metadata_WellRow  Metadata_WellCol Metadata_gene_name Metadata_genotype  \
# 0                C                 6                NF1                WT
# 1                C                 6                NF1                WT
# 2                C                 6                NF1                WT
# 3                C                 6                NF1                WT
# 4                C                 6                NF1                WT
#
#   Metadata_ImageNumber Metadata_Plate Metadata_Well  \
# 0                    1            001            C6
# 1                    1            001            C6
# 2                    1            001            C6
# 3                    1            001            C6
# 4                    1            001            C6
#
#   Metadata_Cytoplasm_Parent_Cells Metadata_Cytoplasm_Parent_Nuclei  \
# 0                               1                                3
# 1                               2                                4
# 2                               3                                5
# 3                               4                                7
# 4                               5                                8
#
#   Metadata_Cells_Number_Object_Number  ...  \
# 0                                   1  ...
# 1                                   2  ...
# 2                                   3  ...
# 3                                   4  ...
# 4                                   5  ...
#
#   Nuclei_Texture_InfoMeas1_RFP_3_02_256  \
# 0                              0.092817
# 1                             -0.576108
# 2                              0.338346
# 3                             -1.519845
# 4                             -0.830923
#
#    Nuclei_Texture_InfoMeas1_RFP_3_03_256  \
# 0                              -1.113483
# 1                               0.502010
# 2                              -0.572459
# 3                               0.118382
# 4                              -1.186324
#
#    Nuclei_Texture_InfoMeas2_GFP_3_00_256  \
# 0                               0.956526
# 1                               0.474898
# 2                               0.621543
# 3                               0.489857
# 4                               0.268354
#
#    Nuclei_Texture_InfoMeas2_GFP_3_02_256  \
# 0                               0.904672
# 1                               0.922557
# 2                               0.737608
# 3                               0.278456
# 4                               0.526774
#
#    Nuclei_Texture_InfoMeas2_RFP_3_00_256  \
# 0                              -0.005997
# 1                              -0.591964
# 2                              -0.484682
# 3                               0.144388
# 4                               0.897291
#
#    Nuclei_Texture_InfoMeas2_RFP_3_01_256  \
# 0                              -0.036913
# 1                               0.074769
# 2                              -0.522132
# 3                               0.742653
# 4                               1.016776
#
#    Nuclei_Texture_InfoMeas2_RFP_3_02_256  \
# 0                               0.685169
# 1                               0.884695
# 2                               0.293870
# 3                               1.295467
# 4                               1.223951
#
#    Nuclei_Texture_InfoMeas2_RFP_3_03_256  \
# 0                               1.281912
# 1                               0.027386
# 2                               0.922769
# 3                               0.554441
# 4                               1.373739
#
#    Nuclei_Texture_InverseDifferenceMoment_GFP_3_03_256  \
# 0                                          -0.319286
# 1                                          -0.724098
# 2                                          -0.292361
# 3                                           0.319486
# 4                                          -0.057416
#
#    Nuclei_Texture_SumVariance_RFP_3_01_256
# 0                                 0.533778
# 1                                 0.001415
# 2                                 0.030412
# 3                                 0.456474
# 4                                 3.365358
#
# [5 rows x 408 columns]

# %% [markdown]
# ---
#
# ### Visualize basic count statistics for Plate 1

# %%
sc_df.Metadata_genotype.value_counts()
# Out:
# Null    173
# WT       69
# Name: Metadata_genotype, dtype: int64

# %%
pd.crosstab(sc_df.Metadata_genotype, sc_df.Metadata_Well)
# Out:
# Metadata_Well      C6  C7  D6  D7  E6  E7  F6  F7
# Metadata_genotype
# Null                0  21   0  29   0  56   0  67
# WT                 25   0   7   0  14   0  23   0

# %% [markdown]
# ---
#
# ## Plate 2

# %% [markdown]
# ### Load and view platemap file

# %%
# Load platemap file
platemap_df2 = pd.read_csv(platemap_file2)
platemap_df2
# Out:
#    WellRow  WellCol well_position gene_name genotype
# 0        A        1            A1       NF1       WT
# 1        A        6            A6       NF1       WT
# 2        A        7            A7       NF1     Null
# 3        A       12           A12       NF1     Null
# 4        B        1            B1       NF1       WT
# 5        B        6            B6       NF1       WT
# 6        B        7            B7       NF1     Null
# 7        B       12           B12       NF1     Null
# 8        C        1            C1       NF1       WT
# 9        C        6            C6       NF1       WT
# 10       C        7            C7       NF1     Null
# 11       C       12           C12       NF1     Null
# 12       D        1            D1       NF1       WT
# 13       D        6            D6       NF1       WT
# 14       D        7            D7       NF1     Null
# 15       D       12           D12       NF1     Null
# 16       E        1            E1       NF1       WT
# 17       E        6            E6       NF1       WT
# 18       E        7            E7       NF1     Null
# 19       E       12           E12       NF1     Null
# 20       F        1            F1       NF1       WT
# 21       F        6            F6       NF1       WT
# 22       F        7            F7       NF1     Null
# 23       F       12           F12       NF1     Null
# 24       G        1            G1       NF1       WT
# 25       G        6            G6       NF1       WT
# 26       G        7            G7       NF1     Null
# 27       G       12           G12       NF1     Null
# 28       H        1            H1       NF1       WT
# 29       H        6            H6       NF1       WT
# 30       H        7            H7       NF1     Null
# 31       H       12           H12       NF1     Null

# %% [markdown]
# ### Set up `SingleCells` class from Pycytominer

# %%
# Instantiate SingleCells class
sc2 = cells.SingleCells(
    sql_file=single_cell_file2,
    compartments=["Per_Cells", "Per_Cytoplasm", "Per_Nuclei"],
    compartment_linking_cols=linking_cols,
    image_table_name="Per_Image",
    strata=["Image_Metadata_Well", "Image_Metadata_Plate"],
    merge_cols=["ImageNumber"],
    image_cols="ImageNumber",
    load_image_data=True
)
# Out:
# /home/jenna/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pycytominer/cyto_utils/util.py:61: UserWarning: Non-canonical compartment detected: per_cells, per_cytoplasm, per_nuclei
#   warnings.warn(warn_str)

# %% [markdown]
# ### Merge single cells

# %%
# Merge single cells across compartments
anno_kwargs = {"join_on": ["Metadata_well_position", "Image_Metadata_Well"]}

sc_df2 = sc2.merge_single_cells(
    platemap=platemap_df2,
    **anno_kwargs,
)

# Save level 2 data as a csv
output(sc_df2, sc_output_file2)

print(sc_df2.shape)
sc_df2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [15], line 4
#       1 # Merge single cells across compartments
#       2 anno_kwargs = {"join_on": ["Metadata_well_position", "Image_Metadata_Well"]}
# ----> 4 sc_df2 = sc2.merge_single_cells(
#       5     platemap=platemap_df2,
#       6     **anno_kwargs,
#       7 )
#       9 # Save level 2 data as a csv
#      10 output(sc_df2, sc_output_file2)
#
# File ~/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pycytominer/cyto_utils/cells.py:739, in SingleCells.merge_single_cells(self, compute_subsample, sc_output_file, compression_options, float_format, single_cell_normalize, normalize_args, platemap, **kwargs)
#     731             sc_df = sc_df.merge(
#     732                 self.load_compartment(compartment=right_compartment),
#     733                 left_on=self.merge_cols + [left_link_col],
#     734                 right_on=self.merge_cols + [right_link_col],
#     735                 suffixes=merge_suffix,
#     736             )
#     738         else:
# --> 739             sc_df = sc_df.merge(
#     740                 self.load_compartment(compartment=right_compartment),
#     741                 left_on=self.merge_cols + [left_link_col],
#     742                 right_on=self.merge_cols + [right_link_col],
#     743                 suffixes=merge_suffix,
#     744             )
#     746         linking_check_cols.append(linking_check)
#     748 # Add metadata prefix to merged suffixes
#
# File ~/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pandas/core/frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
#    9355         suffixes=suffixes,
#    9356         copy=copy,
#    9357         indicator=indicator,
#    9358         validate=validate,
#    9359     )
#
# File ~/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pandas/core/reshape/merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     693 self._cross = cross_col
#     695 # note this function has side effects
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
# --> 700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
#     704 self._maybe_coerce_merge_keys()
#
# File ~/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pandas/core/reshape/merge.py:1110, in _MergeOperation._get_merge_keys(self)
#    1108     right_keys.append(rk)
#    1109 if lk is not None:
# -> 1110     left_keys.append(left._get_label_or_level_values(lk))
#    1111     join_names.append(lk)
#    1112 else:
#    1113     # work-around for merge_asof(left_index=True)
#
# File ~/anaconda3/envs/4.process-nf1-features/lib/python3.8/site-packages/pandas/core/generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'Cytoplasm_Parent_Nuclei'

# %% [markdown]
# ### Normalize data

# %%
# Normalize single cell data and write to file
normalize_sc_df2 = normalize(
    sc_df2,
    method="standardize"
)

output(normalize_sc_df2, sc_norm_output_file2)

print(normalize_sc_df2.shape)
normalize_sc_df2.head()

# %% [markdown]
# ### Feature selection

# %%
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "blocklist",
]

feature_select_norm_sc_df2 = feature_select(
    normalize_sc_df2,
    operation=feature_select_ops
)

output(feature_select_norm_sc_df2, sc_norm_fs_output_file2)

print(feature_select_norm_sc_df2.shape)
feature_select_norm_sc_df2.head()

# %% [markdown]
# ---
#
# ### Visualize basic count statistics for Plate 2

# %%
sc_df2.Metadata_genotype.value_counts()

# %%
pd.crosstab(sc_df2.Metadata_genotype, sc_df2.Metadata_Well)
