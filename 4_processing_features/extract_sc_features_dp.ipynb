# %% [markdown]
# # Process single cell morphology features for DeepProfiler readouts

# %% [markdown]
# ## Import libraries

# %%
import pathlib
import pandas as pd

from pycytominer import feature_select
from pycytominer.cyto_utils import DeepProfiler_processing, output, infer_cp_features

# %% [markdown]
# ## Set paths to DP project

# %%
dp_output_nuc = pathlib.Path("../3_extracting_features/NF1_nuc_project-DP")
dp_output_cyto = pathlib.Path("../3_extracting_features/NF1_cyto_project-DP")

index_file_nuc = pathlib.Path(f"{dp_output_nuc}/inputs/metadata/index.csv")
index_file_cyto = pathlib.Path(f"{dp_output_cyto}/inputs/metadata/index.csv")


profile_dir_nuc = pathlib.Path(f"{dp_output_nuc}/outputs/efn_pretrained/features")
profile_dir_cyto = pathlib.Path(f"{dp_output_cyto}/outputs/efn_pretrained/features")

# %% [markdown]
# ## Set paths to outputs

# %%
output_dir = pathlib.Path('data')

output_file_raw_nuc = pathlib.Path(f'{output_dir}/nf1_sc_deepprofiler_nuc.csv.gz')
output_file_raw_cyto = pathlib.Path(f'{output_dir}/nf1_sc_deepprofiler_cyto.csv.gz')

output_file_norm_nuc = pathlib.Path(f'{output_dir}/nf1_sc_norm_deepprofiler_nuc.csv.gz')
output_file_norm_cyto = pathlib.Path(f'{output_dir}/nf1_sc_norm_deepprofiler_cyto.csv.gz')

output_file_norm_fs_nuc = pathlib.Path(f'{output_dir}/nf1_sc_norm_fs_deepprofiler_nuc.csv.gz')
output_file_norm_fs_cyto = pathlib.Path(f'{output_dir}/nf1_sc_norm_fs_deepprofiler_cyto.csv.gz')

# %% [markdown]
# ## Perform normalization and feature selection on DP Nuclei project

# %% [markdown]
# ### Create DeepProfilerData object

# %%
deep_data_nuc = DeepProfiler_processing.DeepProfilerData(
    index_file_nuc, profile_dir_nuc, filename_delimiter="/", file_extension=".npz"
)

# %% [markdown]
# ### Initalize SingleCellDeepProfiler class

# %%
deep_single_cell_nuc = DeepProfiler_processing.SingleCellDeepProfiler(deep_data_nuc)

# %% [markdown]
# ### Compile raw single cell data

# %%
nuc_sc = deep_single_cell_nuc.get_single_cells(output=True, location_x_col_index=1, location_y_col_index=2)
output(nuc_sc, output_file_raw_nuc)

print(nuc_sc.shape)
nuc_sc.head()
# Out:
# (257, 3852)
#    Location_Center_X  Location_Center_Y Metadata_Plate Metadata_Well  \
# 0         652.868421         760.552632              1            D6
# 1        1015.898477         209.162437              1            F6
# 2         387.202830         238.853774              1            F6
# 3         259.502304         250.400922              1            F6
# 4         351.255708         592.429224              1            F6
#
#   Metadata_Site Metadata_Plate_Map_Name  \
# 0             3                  1_D6_3
# 1             2                  1_F6_2
# 2             2                  1_F6_2
# 3             2                  1_F6_2
# 4             2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  ...  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
#
#   efficientnet_3830 efficientnet_3831  efficientnet_3832  efficientnet_3833  \
# 0         -0.189552         -0.034666           0.636435          -0.144796
# 1         -0.130013         -0.169359           0.309454          -0.167421
# 2         -0.154498         -0.107800           1.008715          -0.173751
# 3          0.048324         -0.167672           1.143355          -0.179259
# 4         -0.165685         -0.157138           0.196759          -0.202028
#
#    efficientnet_3834  efficientnet_3835  efficientnet_3836  efficientnet_3837  \
# 0          -0.169194          -0.166081          -0.033387          -0.097380
# 1          -0.211234           0.452966          -0.092908          -0.161609
# 2          -0.113082          -0.186560          -0.044206          -0.105374
# 3          -0.180391          -0.162171          -0.055307          -0.079885
# 4          -0.010776          -0.224092          -0.041582          -0.147533
#
#    efficientnet_3838  efficientnet_3839
# 0          -0.104920           0.216034
# 1          -0.135684           0.470573
# 2          -0.082019           0.585320
# 3          -0.127507           0.332103
# 4          -0.124860           0.300342
#
# [5 rows x 3852 columns]

# %% [markdown]
# ### Normalize raw single cell data

# %%
normalized_nuc = deep_single_cell_nuc.normalize_deep_single_cells(
    output_file=output_file_norm_nuc, location_x_col_index=1, location_y_col_index=2
)

print(normalized_nuc.shape)
normalized_nuc.head()
# Out:
# getting single cells
# (257, 3852)
#    Location_Center_X  Location_Center_Y Metadata_Plate Metadata_Well  \
# 0         652.868421         760.552632              1            D6
# 1        1015.898477         209.162437              1            F6
# 2         387.202830         238.853774              1            F6
# 3         259.502304         250.400922              1            F6
# 4         351.255708         592.429224              1            F6
#
#   Metadata_Site Metadata_Plate_Map_Name  \
# 0             3                  1_D6_3
# 1             2                  1_F6_2
# 2             2                  1_F6_2
# 3             2                  1_F6_2
# 4             2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  ...  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
#
#   efficientnet_3830 efficientnet_3831  efficientnet_3832  efficientnet_3833  \
# 0         -0.514201          0.478099           0.484105          -0.212163
# 1         -0.250138         -0.740111          -0.190505          -0.690312
# 2         -0.358730         -0.183352           1.252175          -0.824103
# 3          0.540821         -0.724848           1.529958          -0.940500
# 4         -0.408348         -0.629579          -0.423012          -1.421697
#
#    efficientnet_3834  efficientnet_3835  efficientnet_3836  efficientnet_3837  \
# 0          -0.572582          -0.239070           0.907958           0.219261
# 1          -0.862426           4.039268          -1.532861          -1.382833
# 2          -0.185720          -0.380602           0.464281           0.019876
# 3          -0.649775          -0.212045           0.009084           0.655653
# 4           0.519623          -0.639995           0.571886          -1.031720
#
#    efficientnet_3838  efficientnet_3839
# 0           0.311132          -0.288884
# 1          -0.336643           0.894669
# 2           0.793334           1.428218
# 3          -0.164469           0.250813
# 4          -0.108736           0.103133
#
# [5 rows x 3852 columns]

# %% [markdown]
# ### Separate metadata and features prior to feature selection

# %%
# extract metadata prior to feature selection
metadata_cols = infer_cp_features(normalized_nuc, metadata=True)
derived_features = [
    x for x in normalized_nuc.columns.tolist() if x not in metadata_cols
]

# %% [markdown]
# ### Feature selection from normalized data

# %%
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "blocklist",
]

feature_select_norm_nuc = feature_select(
    normalized_nuc,
    features = derived_features,
    operation= feature_select_ops,
)

output(feature_select_norm_nuc, output_file_norm_fs_nuc)

print(feature_select_norm_nuc.shape)
feature_select_norm_nuc.head()
# Out:
# (257, 3837)
#    Location_Center_X  Location_Center_Y Metadata_Plate Metadata_Well  \
# 0         652.868421         760.552632              1            D6
# 1        1015.898477         209.162437              1            F6
# 2         387.202830         238.853774              1            F6
# 3         259.502304         250.400922              1            F6
# 4         351.255708         592.429224              1            F6
#
#   Metadata_Site Metadata_Plate_Map_Name  \
# 0             3                  1_D6_3
# 1             2                  1_F6_2
# 2             2                  1_F6_2
# 3             2                  1_F6_2
# 4             2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  ...  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
#
#   efficientnet_3830 efficientnet_3831  efficientnet_3832  efficientnet_3833  \
# 0         -0.514201          0.478099           0.484105          -0.212163
# 1         -0.250138         -0.740111          -0.190505          -0.690312
# 2         -0.358730         -0.183352           1.252175          -0.824103
# 3          0.540821         -0.724848           1.529958          -0.940500
# 4         -0.408348         -0.629579          -0.423012          -1.421697
#
#    efficientnet_3834  efficientnet_3835  efficientnet_3836  efficientnet_3837  \
# 0          -0.572582          -0.239070           0.907958           0.219261
# 1          -0.862426           4.039268          -1.532861          -1.382833
# 2          -0.185720          -0.380602           0.464281           0.019876
# 3          -0.649775          -0.212045           0.009084           0.655653
# 4           0.519623          -0.639995           0.571886          -1.031720
#
#    efficientnet_3838  efficientnet_3839
# 0           0.311132          -0.288884
# 1          -0.336643           0.894669
# 2           0.793334           1.428218
# 3          -0.164469           0.250813
# 4          -0.108736           0.103133
#
# [5 rows x 3837 columns]

# %% [markdown]
# ## Perform normalization and feature selection on DP Nuclei project

# %% [markdown]
# ### Create DeepProfilerData object

# %%
deep_data_cyto = DeepProfiler_processing.DeepProfilerData(
    index_file_cyto, profile_dir_cyto, filename_delimiter="/", file_extension=".npz"
)

# %% [markdown]
# ### Initialize SingleDeepProfiler class

# %%
deep_single_cell_cyto = DeepProfiler_processing.SingleCellDeepProfiler(deep_data_cyto)

# %% [markdown]
# ### Compile raw single cell data

# %%
cyto_sc = deep_single_cell_cyto.get_single_cells(output=True, location_x_col_index=1, location_y_col_index=2)
output(cyto_sc, output_file_raw_cyto)

print(cyto_sc.shape)
cyto_sc.head()
# Out:
# (256, 3852)
#    Location_Center_X  Location_Center_Y Metadata_Plate Metadata_Well  \
# 0         650.422472         736.706742              1            D6
# 1         949.182667         256.734667              1            F6
# 2         454.460081         265.797023              1            F6
# 3         211.165254         274.745763              1            F6
# 4         375.125130         566.646507              1            F6
#
#   Metadata_Site Metadata_Plate_Map_Name  \
# 0             3                  1_D6_3
# 1             2                  1_F6_2
# 2             2                  1_F6_2
# 3             2                  1_F6_2
# 4             2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  ...  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
#
#   efficientnet_3830 efficientnet_3831  efficientnet_3832  efficientnet_3833  \
# 0          0.153386         -0.034785          -0.113517          -0.173233
# 1          0.158114         -0.099159          -0.174047           0.415832
# 2          0.107825         -0.194261          -0.185260          -0.035056
# 3         -0.138649         -0.175582          -0.128276          -0.110945
# 4          0.122260         -0.110667          -0.155417          -0.143916
#
#    efficientnet_3834  efficientnet_3835  efficientnet_3836  efficientnet_3837  \
# 0           0.013302          -0.175570          -0.112678          -0.030428
# 1          -0.184661          -0.034013          -0.076901          -0.028081
# 2           0.167735           0.560817          -0.104378          -0.064447
# 3          -0.067334           0.173986          -0.101229          -0.025802
# 4          -0.120184           0.051254          -0.054232          -0.037242
#
#    efficientnet_3838  efficientnet_3839
# 0          -0.098558           0.458548
# 1          -0.116231           0.030506
# 2          -0.133140           0.303427
# 3          -0.090082           0.448318
# 4          -0.086592           0.667034
#
# [5 rows x 3852 columns]

# %% [markdown]
# ### Normalize raw single cell data

# %%
normalized_cyto = deep_single_cell_cyto.normalize_deep_single_cells(
    output_file=output_file_norm_cyto, location_x_col_index=1, location_y_col_index=2
)

print(normalized_cyto.shape)
normalized_cyto.head()
# Out:
# getting single cells
# (256, 3852)
#    Location_Center_X  Location_Center_Y Metadata_Plate Metadata_Well  \
# 0         650.422472         736.706742              1            D6
# 1         949.182667         256.734667              1            F6
# 2         454.460081         265.797023              1            F6
# 3         211.165254         274.745763              1            F6
# 4         375.125130         566.646507              1            F6
#
#   Metadata_Site Metadata_Plate_Map_Name  \
# 0             3                  1_D6_3
# 1             2                  1_F6_2
# 2             2                  1_F6_2
# 3             2                  1_F6_2
# 4             2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  ...  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
#
#   efficientnet_3830 efficientnet_3831  efficientnet_3832  efficientnet_3833  \
# 0         -0.034014          0.859518          -0.025713          -0.729571
# 1         -0.021109          0.185511          -0.612227           2.925806
# 2         -0.158382         -0.810211          -0.720877           0.127869
# 3         -0.831178         -0.614643          -0.168719          -0.343051
# 4         -0.118977          0.065025          -0.431710          -0.547652
#
#    efficientnet_3834  efficientnet_3835  efficientnet_3836  efficientnet_3837  \
# 0           0.267231          -0.847366          -1.090082           0.566786
# 1          -0.927761          -0.304350          -0.031065           0.626545
# 2           1.199453           1.977439          -0.844405          -0.299137
# 3          -0.219525           0.493543          -0.751189           0.684555
# 4          -0.538548           0.022739           0.639954           0.393346
#
#    efficientnet_3838  efficientnet_3839
# 0          -0.024363           0.230463
# 1          -0.408060          -1.211616
# 2          -0.775166          -0.292143
# 3           0.159646           0.196000
# 4           0.235406           0.932857
#
# [5 rows x 3852 columns]

# %% [markdown]
# ### Separate metadata and features prior to feature selection

# %%
# extract metadata prior to feature selection
metadata_cols = infer_cp_features(normalized_cyto, metadata=True)
derived_features = [
    x for x in normalized_cyto.columns.tolist() if x not in metadata_cols
]

# %% [markdown]
# ### Feature selection from normalized data

# %%
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "blocklist",
]

feature_select_norm_cyto = feature_select(
    normalized_cyto,
    features = derived_features,
    operation= feature_select_ops,
)

output(feature_select_norm_cyto, output_file_norm_fs_cyto)

print(feature_select_norm_cyto.shape)
feature_select_norm_cyto.head()
# Out:
# (256, 3844)
#    Location_Center_X  Location_Center_Y Metadata_Plate Metadata_Well  \
# 0         650.422472         736.706742              1            D6
# 1         949.182667         256.734667              1            F6
# 2         454.460081         265.797023              1            F6
# 3         211.165254         274.745763              1            F6
# 4         375.125130         566.646507              1            F6
#
#   Metadata_Site Metadata_Plate_Map_Name  \
# 0             3                  1_D6_3
# 1             2                  1_F6_2
# 2             2                  1_F6_2
# 3             2                  1_F6_2
# 4             2                  1_F6_2
#
#                                         Metadata_DNA  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                          Metadata_ER  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...
#
#                                       Metadata_Actin Metadata_Genotype  ...  \
# 0  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 1  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 2  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 3  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
# 4  ../../../../1_preprocessing_data/Corrected_Ima...                WT  ...
#
#   efficientnet_3830 efficientnet_3831  efficientnet_3832  efficientnet_3833  \
# 0         -0.034014          0.859518          -0.025713          -0.729571
# 1         -0.021109          0.185511          -0.612227           2.925806
# 2         -0.158382         -0.810211          -0.720877           0.127869
# 3         -0.831178         -0.614643          -0.168719          -0.343051
# 4         -0.118977          0.065025          -0.431710          -0.547652
#
#    efficientnet_3834  efficientnet_3835  efficientnet_3836  efficientnet_3837  \
# 0           0.267231          -0.847366          -1.090082           0.566786
# 1          -0.927761          -0.304350          -0.031065           0.626545
# 2           1.199453           1.977439          -0.844405          -0.299137
# 3          -0.219525           0.493543          -0.751189           0.684555
# 4          -0.538548           0.022739           0.639954           0.393346
#
#    efficientnet_3838  efficientnet_3839
# 0          -0.024363           0.230463
# 1          -0.408060          -1.211616
# 2          -0.775166          -0.292143
# 3           0.159646           0.196000
# 4           0.235406           0.932857
#
# [5 rows x 3844 columns]
